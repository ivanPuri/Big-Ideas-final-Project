# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# here i am just importing pandas and matplotlib

# %%
def load_my_csv():
    csv_path = "6dfd4f8f-cbf5-4917-a5eb-fd07f4403167.csv"  
    return pd.read_csv(csv_path)

# %% [markdown]
# function to load in a csv, its hard coded so it has no use, its just for making the main cleaner

# %%
def isolate_column(df, column_name):
    if df is None or df.empty:
        print(f"error my friend, {column_name}")
        return None

    if column_name not in df.columns:
        print(f"error my friend, {column_name}")
        return None

    return df[[column_name]]

# %% [markdown]
# this function isolates a col from the df

# %%
# Out:
# neighborhood
# Crafton Heights              98.000000
# Elliott                      97.000000
# Point Breeze North           88.000000
# Regent Square                86.000000
# St. Clair                    85.000000
#                                ...
# Bluff                        14.666667
# Lincoln Place                14.000000
# Allegheny West               11.000000
# Central Business District     6.000000
# South Side Flats              3.000000
# Name: percent_over_limit, Length: 62, dtype: float64

# %%
# plotting the graph
plt.figure(figsize=(12, 6))
avg_percent.plot(kind='bar', color='red', edgecolor='black')
plt.ylabel('Average % Over Speed Limit')
plt.xlabel('Neighborhood')
plt.title('Average Percent Over Speed Limit by Neighborhood')
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 100)
plt.tight_layout()
plt.show()

# %% [markdown]
# What is going on here?
#
# There is a data set that has the info for every neighborhood in pittsburgh, within every nieghborhood there are multiple locations where the speed of vehicles passing is being tracked. I focused on the metric that showed the % of cars or bikes that went by that intersection above the speed limit. I then took the average for all of the locations for each neighborhood in order to get the average % of cars that speed per neighborhood. This way I could quantify the best neighborhood as the safest due to the fact that it is the one where most people are following road laws. I displayed it on a graph in decending order so it would also be easy to see
